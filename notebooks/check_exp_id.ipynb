# %%
import mlflow
import os

os.chdir('/home/mai/notebooks/final_thesis/')

experiment = mlflow.get_experiment_by_name("nb_priors_tuning")
print(experiment.experiment_id)
# Out:
# 6

# %%
experiments = mlflow.search_experiments()
for exp in experiments:
    print(exp.experiment_id, exp.name)
# Out:
# 7 svm_calibrated_grid_search
# 6 nb_priors_tuning
# 0 Default
